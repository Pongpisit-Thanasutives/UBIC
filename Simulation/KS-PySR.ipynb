# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import sys; sys.path.append('../')
from misc import h5file
import numpy as np

import scipy.io as sio
import sympy
from sympy import Symbol, parse_expr, sympify, lambdify, Lambda

import pandas as pd
import subprocess

from scipy.optimize import curve_fit

MAIN_SEED = 1234

# %%
data = sio.loadmat('../Datasets/kuramoto_sivishinky.mat')
x = data['x'].real.reshape(-1, 1)

# %%
un = np.load("../Examples/denoised_files/KS_noise30_reduced_dctV2ksvdreg_25x25.npy")
# un = data['uu']

# %%
from pysr import PySRRegressor

deterministic = True

if not deterministic:
    model = PySRRegressor(
        niterations=200,  # < Increase me for better results
        binary_operators=["+", "*"],
        unary_operators=["sin", "cos"], 
        deterministic=deterministic
    )
else:
    np.random.seed(MAIN_SEED)
    model = PySRRegressor(
        niterations=200,  # < Increase me for better results
        binary_operators=["+", "*"],
        unary_operators=["sin", "cos"], 
        # For a deterministic result
        deterministic=deterministic, 
        random_state=MAIN_SEED, 
        procs=0, 
        multithreading=False
    )

# %%
model.fit(x, un[:,0])
# Out:
# /Users/pongpisit/anaconda3/envs/pysr_latest/lib/python3.11/site-packages/pysr/sr.py:1289: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Users/pongpisit/anaconda3/envs/pysr_latest/lib/python3.11/site-packages/pysr/julia_helpers.py:197: UserWarning: Your system's Python library is static (e.g., conda), so precompilation will be turned off. For a dynamic library, try `pyenv`.
#   warnings.warn(
# Started!
#
# Cycles per second: 2.560e+04
# Progress: 71 / 3000 total iterations (2.367%)
# ...
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.171e-01  -1.000e-10  0.0062899655
# 3           6.138e-01  2.690e-03  (-0.0009967288 * x0)
# 4           1.321e-01  1.536e+00  cos(-0.06301786 * x0)
# 5           1.321e-01  2.340e-04  cos(sin(-0.06301786) * x0)
# ...
